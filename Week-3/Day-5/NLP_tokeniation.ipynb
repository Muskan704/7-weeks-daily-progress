# %%
import nltk
# Download tokenizer models
nltk.download('punkt')
nltk.download('punkt_tab')   # Required for newer NLTK versions
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ChaudhariMuskan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\ChaudhariMuskan\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ChaudhariMuskan\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# IMPORT LIBRARIES
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from collections import Counter

# %%
# Sample text
text = """
Natural Language Processing (NLP) is a field of Artificial Intelligence
that enables computers to understand, interpret, and generate human language.
Tokenization is the first step in NLP.
"""

# %%
# Sentence Tokenization
sentences = sent_tokenize(text)

print("Sentence Tokenization:")
for i, sentence in enumerate(sentences, 1):
    print(f"{i}: {sentence}")
# Out:
# Sentence Tokenization:
# 1:
# Natural Language Processing (NLP) is a field of Artificial Intelligence
# that enables computers to understand, interpret, and generate human language.
# 2: Tokenization is the first step in NLP.

# %%
#  Word Tokenization
words = word_tokenize(text)

print("\nWord Tokenization:")
print(words)
# Out:
# Word Tokenization:
# ['Natural', 'Language', 'Processing', '(', 'NLP', ')', 'is', 'a', 'field', 'of', 'Artificial', 'Intelligence', 'that', 'enables', 'computers', 'to', 'understand', ',', 'interpret', ',', 'and', 'generate', 'human', 'language', '.', 'Tokenization', 'is', 'the', 'first', 'step', 'in', 'NLP', '.']

# %%
# Remove Stopwords
stop_words = set(stopwords.words('english'))

filtered_words = [
    word for word in words
    if word.lower() not in stop_words and word.isalpha()
]

print("\nFiltered Tokens (without stopwords):")
print(filtered_words)
# Out:
# Filtered Tokens (without stopwords):
# ['Natural', 'Language', 'Processing', 'NLP', 'field', 'Artificial', 'Intelligence', 'enables', 'computers', 'understand', 'interpret', 'generate', 'human', 'language', 'Tokenization', 'first', 'step', 'NLP']

# %%
# Token Frequency
from collections import Counter

word_freq = Counter(filtered_words)

print("\nWord Frequency:")
for word, freq in word_freq.items():
    print(f"{word}: {freq}")
# Out:
# Word Frequency:
# Natural: 1
# Language: 1
# Processing: 1
# NLP: 2
# field: 1
# Artificial: 1
# Intelligence: 1
# enables: 1
# computers: 1
# understand: 1
# interpret: 1
# generate: 1
# human: 1
# language: 1
# Tokenization: 1
# first: 1
# step: 1
