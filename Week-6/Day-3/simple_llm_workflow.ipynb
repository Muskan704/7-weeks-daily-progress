# %%
from langgraph.graph import StateGraph, START, END
from langchain_google_genai import ChatGoogleGenerativeAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash"
)

# %%
# create a state

class LLMState(TypedDict):

    question: str 
    answer: str

# %%
def llm_qa(state: LLMState) -> LLMState:

    #extract the question from the state
    question = state['question']

    # form a prompt 
    prompt = f"Answer the following question {question}"

    # ask that question to the llm
    answer = model.invoke(prompt).content

    # update the answer in the state
    state['answer'] = answer 

    return state

# %%
# create a graph

graph = StateGraph(LLMState)

# add nodes
graph.add_node('llm_qa', llm_qa)

# add edges
graph.add_edge(START, 'llm_qa')
graph.add_edge('llm_qa',END)

# compile 
workflow = graph.compile()

# %%
# execute

initial_state = {'question': 'How far is moon from the earth'}

final_state = workflow.invoke(initial_state)

print(final_state['answer'])
# Out:
# The distance between the Earth and the Moon is not constant because the Moon orbits the Earth in an elliptical path.
#
# Here's a breakdown:
#
# *   **Average Distance:** Approximately **384,400 kilometers** (km) or about **238,900 miles**.
# *   **Perigee (closest point):** Around **363,104 km** (225,622 miles)
# *   **Apogee (farthest point):** Around **405,696 km** (252,088 miles)
#
# To put it into perspective, you could fit all the other planets in our solar system (Mercury, Venus, Mars, Jupiter, Saturn, Uranus, Neptune) side-by-side between the Earth and the Moon, with a bit of space left over!

# %%
model.invoke('How far is moon from the earth').content
# Out:
# "The average distance from the Earth to the Moon is approximately **384,400 kilometers (238,900 miles)**.\n\nHowever, this distance isn't constant because the Moon's orbit around Earth is elliptical, not a perfect circle. So, the distance varies:\n\n*   **Perigee (closest point):** About 363,104 km (225,622 miles)\n*   **Apogee (farthest point):** About 405,696 km (252,088 miles)\n\nIt takes light about **1.28 seconds** to travel from the Moon to the Earth."
