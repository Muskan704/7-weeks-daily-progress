# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
from langgraph.checkpoint.memory import InMemorySaver

# %%
load_dotenv()
# Out:
# True

# %%
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash"
)

# %%
class JokeState(TypedDict):
     topic: str 
     joke: str 
     explanation: str

# %%
def generate_joke(state: JokeState):

    prompt = f'generate a joke on the topic {state["topic"]}'
    response = llm.invoke(prompt).content

    return {'joke': response}

# %%
def generate_explanation(state: JokeState):

    prompt = f'write an explanation for the joke - {state["joke"]}'
    response = llm.invoke(prompt).content 

    return {'explanation': response}

# %%
graph = StateGraph(JokeState)

graph.add_node('generate_joke', generate_joke)
graph.add_node('generate_explanation', generate_explanation)

graph.add_edge(START, 'generate_joke')
graph.add_edge('generate_joke', 'generate_explanation')
graph.add_edge('generate_explanation', END)

checkpointer = InMemorySaver()

workflow = graph.compile(checkpointer=checkpointer)

# %%
config1 = {"configurable": {"thread_id":"1"}}
workflow.invoke({'topic':'pizza'}, config = config1)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File c:\Users\ChaudhariMuskan\Aditi_Projects\7-Weeks-Daily-Progress\Week-6\LangGraph\myenv\Lib\site-packages\langchain_google_genai\chat_models.py:3194, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3193 try:
# -> 3194     response: GenerateContentResponse = self.client.models.generate_content(
#    3195         **request,
#    3196     )
#    3197 except ClientError as e:
#
# File c:\Users\ChaudhariMuskan\Aditi_Projects\7-Weeks-Daily-Progress\Week-6\LangGraph\myenv\Lib\site-packages\google\genai\models.py:6454, in Models.generate_content(self, model, contents, config)
#    6453 i += 1
# -> 6454 response = self._generate_content(
#    6455     model=model, contents=contents, config=parsed_config
# ...

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza get a job?\n\nBecause it kneaded dough!', 'explanation': 'This joke is a classic pun! It plays on the similar sound of two phrases with very different meanings:\n\n1.  **"Kneaded dough" (literal for pizza):** When you make pizza (or bread), you have to **knead** the **dough**. "To knead" means to work and press it with your hands to develop the gluten and make it elastic. So, a pizza, in its very essence, is something that involves "kneading dough."\n\n2.  **"Needed dough" (slang for money):**\n    *   "Needed" is the past tense of "to need," meaning to require something.\n    *   "Dough" is a common slang term for **money**.\n    *   So, if someone "needed dough," it means they needed money.\n\nThe joke is funny because it takes the pizza\'s literal connection to "kneading dough" (the food item) and uses it to sound like the reason a person would get a job – because they "needed dough" (money).'}, next=(), config={'c
# ...

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza get a job?\n\nBecause it kneaded dough!', 'explanation': 'This joke is a classic pun! It plays on the similar sound of two phrases with very different meanings:\n\n1.  **"Kneaded dough" (literal for pizza):** When you make pizza (or bread), you have to **knead** the **dough**. "To knead" means to work and press it with your hands to develop the gluten and make it elastic. So, a pizza, in its very essence, is something that involves "kneading dough."\n\n2.  **"Needed dough" (slang for money):**\n    *   "Needed" is the past tense of "to need," meaning to require something.\n    *   "Dough" is a common slang term for **money**.\n    *   So, if someone "needed dough," it means they needed money.\n\nThe joke is funny because it takes the pizza\'s literal connection to "kneading dough" (the food item) and uses it to sound like the reason a person would get a job – because they "needed dough" (money).'}, next=(), config={'
# ...

# %%
config2 = {"configurable": {"thread_id":"2"}}
workflow.invoke({'topic':'pasta'}, config = config2)
# Out:
# {'topic': 'pasta',
#  'joke': 'Why did the pasta break up with the sauce?\n\nBecause it felt too *saucy*!',
# ...

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza get a job?\n\nBecause it kneaded dough!', 'explanation': 'This joke is a classic pun! It plays on the similar sound of two phrases with very different meanings:\n\n1.  **"Kneaded dough" (literal for pizza):** When you make pizza (or bread), you have to **knead** the **dough**. "To knead" means to work and press it with your hands to develop the gluten and make it elastic. So, a pizza, in its very essence, is something that involves "kneading dough."\n\n2.  **"Needed dough" (slang for money):**\n    *   "Needed" is the past tense of "to need," meaning to require something.\n    *   "Dough" is a common slang term for **money**.\n    *   So, if someone "needed dough," it means they needed money.\n\nThe joke is funny because it takes the pizza\'s literal connection to "kneading dough" (the food item) and uses it to sound like the reason a person would get a job – because they "needed dough" (money).'}, next=(), config={'c
# ...

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza get a job?\n\nBecause it kneaded dough!', 'explanation': 'This joke is a classic pun! It plays on the similar sound of two phrases with very different meanings:\n\n1.  **"Kneaded dough" (literal for pizza):** When you make pizza (or bread), you have to **knead** the **dough**. "To knead" means to work and press it with your hands to develop the gluten and make it elastic. So, a pizza, in its very essence, is something that involves "kneading dough."\n\n2.  **"Needed dough" (slang for money):**\n    *   "Needed" is the past tense of "to need," meaning to require something.\n    *   "Dough" is a common slang term for **money**.\n    *   So, if someone "needed dough," it means they needed money.\n\nThe joke is funny because it takes the pizza\'s literal connection to "kneading dough" (the food item) and uses it to sound like the reason a person would get a job – because they "needed dough" (money).'}, next=(), config={'
# ...

# %% [markdown]
# Time Travel

# %%
workflow.get_state({"configurable": {"thread_id":"1", "checkpoint_id": "1f16346e-f55e-699d-bfff-0edf2d36dfc8"}})
# Out:
# StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_id': '1f16346e-f55e-699d-bfff-0edf2d36dfc8'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-06-08T14:32:53.944156+00:00', parent_config=None, tasks=(PregelTask(id='00c23b02-27fe-7d92-56c8-ef1faa37b5d7', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=())

# %%
workflow.invoke(None, {"configurable": {"thread_id": "1", "checkpoint_id": "1f16346e-f55e-699d-bfff-0edf2d36dfc8"}})
# Out:
# {'topic': 'pizza',
#  'joke': 'Why did the pizza chef go to art school?\n\nHe wanted to learn how to make a perfect **pie-chart**!',
# ...

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza chef go to art school?\n\nHe wanted to learn how to make a perfect **pie-chart**!', 'explanation': 'This joke is a classic pun, playing on the word "pie" and its two very different meanings:\n\n1.  **A "pie" (food item):** A pizza chef is an expert at making pizzas, which are often referred to as "pizza pies." This is what you\'d expect a pizza chef to be good at.\n\n2.  **A "pie-chart" (data visualization):** A pie-chart is a type of graph used to display data, where a circle is divided into segments, each representing a proportion of the whole – much like slices of a pie. Creating clear and effective pie-charts is a skill often taught in graphic design or data visualization courses, which can be part of an art school curriculum.\n\nThe humor comes from the **unexpected twist**. You\'d expect a pizza chef to be interested in culinary skills related to *edible* pies. The punchline cleverly misdirects, suggesting he w
# ...

# %% [markdown]
# Updating state

# %%
workflow.update_state({"configurable": {"thread_id":"1", "checkpoint_id": "1f16346e-f55e-699d-bfff-0edf2d36dfc8","checkpoint_ns": ""}}, {'topic':'samosa'})
# Out:
# {'configurable': {'thread_id': '1',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f163477-cdb2-67d4-8000-99f83c4cc89d'}}

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'samosa'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f163477-cdb2-67d4-8000-99f83c4cc89d'}}, metadata={'source': 'update', 'step': 0, 'parents': {}}, created_at='2026-06-08T14:36:51.376123+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f16346e-f55e-699d-bfff-0edf2d36dfc8'}}, tasks=(PregelTask(id='9727cccd-4ef2-e1d3-a27b-318b429dc283', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result=None),), interrupts=()),
# ...

# %%
workflow.invoke(None, {"configurable": {"thread_id": "1", "checkpoint_id": "1f16346e-f55e-699d-bfff-0edf2d36dfc8"}})
# Out:
# {'topic': 'pizza',
#  'joke': 'Why did the pizza get a job as a motivational speaker?\n\nBecause it always offered a *slice* of inspiration!',
# ...

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza get a job as a motivational speaker?\n\nBecause it always offered a *slice* of inspiration!', 'explanation': 'This joke is a pun that plays on the word **"slice."**\n\nHere\'s why it\'s funny:\n\n1.  **Literal Meaning (Pizza):** A pizza is famously cut into **slices**. This is a fundamental characteristic of pizza.\n2.  **Figurative Meaning (Inspiration):** The phrase "a slice of [something]" can also be used informally to mean "a small portion" or "a bit of [something]" (e.g., "a slice of life," "a slice of the pie"). So, "a slice of inspiration" means "a little bit of inspiration" or "some inspiration."\n3.  **The Pun:** The humor comes from the unexpected combination. The joke takes the literal characteristic of a pizza (having slices) and applies it to the abstract concept of providing encouragement, using the double meaning of "slice."\n\nSo, the pizza is a good motivational speaker because, like a good pizza, i
# ...

# %% [markdown]
# Fault Tolerance

# %%
from langgraph.graph import StateGraph, END
from langgraph.checkpoint.memory import InMemorySaver
from typing import TypedDict 
import time

# %%
class CrashState(TypedDict):
    input: str 
    step1: str 
    step2: str

# %%
def step_1(state: CrashState) -> CrashState:
    print("Step 1 executed")
    return {"step1":"done", "input": state["input"]}

def step_2(state: CrashState) -> CrashState:
    print("Step 2 hanging... now manually interrupt from the notebook toolbar (STOP button)")
    time.sleep(1000)  # Simulate long-running hang
    return {"step2": "done"}

def step_3(state: CrashState) -> CrashState:
    print("Step 3 executed")
    return {"done": True}

# %%
builder = StateGraph(CrashState)

builder.add_node("step_1", step_1)
builder.add_node("step_2", step_2)
builder.add_node("step_3", step_3)

builder.set_entry_point("step_1")
builder.add_edge("step_1", "step_2")
builder.add_edge("step_2", "step_3")
builder.add_edge("step_3", END)

checkpointer = InMemorySaver()
graph = builder.compile(checkpointer=checkpointer)

# %%
try:
    print("Running graph: Please manually interrupt during Step 2...")
    graph.invoke({"input": "start"}, config={"configurable": {"thread_id": 'thread-1'}})
except KeyboardInterrupt:
    print("Kernel manually interrupted (crash simulated).")
# Out:
# Running graph: Please manually interrupt during Step 2...
# Step 1 executed
# Step 2 hanging... now manually interrupt from the notebook toolbar (STOP button)

# %%
print("\n Re-running the graph to demonstrate fault tolerance...")
final_state = graph.invoke(None, config={"configurable": {"thread_id": 'thread-1'}})
print("\n Final State:", final_state)

# %%
list(graph.get_state_history({"configurable": {"thread_id": 'thread-1'}}))
